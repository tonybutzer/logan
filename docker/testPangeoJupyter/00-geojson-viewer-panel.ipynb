# %%
#! pip install folium

# %%
import folium
import geopandas as gpd
tiles=" http://mt1.google.com/vt/lyrs=y&z={z}&x={x}&y={y}"
attr="Google"


class Fmap():

	def __init__(self,color='blue'):
                print("creating Fmap class")
                self.color = color

	def sat_geojson(self, geojson_bb_file):
                
                my_geo = gpd.read_file(geojson_bb_file)
                center=my_geo.geometry[0].bounds[1], my_geo.geometry[0].bounds[0]
                sw = center
                ne = my_geo.geometry[0].bounds[3], my_geo.geometry[0].bounds[2]
                map3 = folium.Map(location=center, zoom_start=12,center=center,tiles=tiles,attr=attr)
                map3.fit_bounds([sw,ne])
                my_geo_json = my_geo.to_json()
                style_function= lambda x:{'color':self.color}
                folium.GeoJson(my_geo_json,style_function).add_to(map3)
                map3.add_child(folium.features.LatLngPopup())
                #map3
                return(map3)

	def map_geojson(self, geojson_bb_file):
                my_geo = gpd.read_file(geojson_bb_file)
                center=my_geo.geometry[0].bounds[1], my_geo.geometry[0].bounds[0]
                sw = center
                ne = my_geo.geometry[0].bounds[3], my_geo.geometry[0].bounds[2]
                map3 = folium.Map(location=center, zoom_start=12,center=center)
                map3.fit_bounds([sw,ne])
                my_geo_json = my_geo.to_json()
                style_function= lambda x:{'color':self.color}
                folium.GeoJson(my_geo_json,style_function).add_to(map3)
                map3.add_child(folium.features.LatLngPopup())
                #map3
                return(map3)

	def add_geojson(self, geojson_bb_file, map3, color='pink'):
                my_geo = gpd.read_file(geojson_bb_file)
                center=my_geo.geometry[0].bounds[1], my_geo.geometry[0].bounds[0]
                sw = center
                ne = my_geo.geometry[0].bounds[3], my_geo.geometry[0].bounds[2]
                #map3 = folium.Map(location=center, zoom_start=12,center=center)
                #map3.fit_bounds([sw,ne])
                my_geo_json = my_geo.to_json()
                style_function= lambda x:{'color':color}
                folium.GeoJson(my_geo_json,style_function).add_to(map3)
                return(map3)

	def ne_geojson(self, geojson_bb_file):
                my_geo = gpd.read_file(geojson_bb_file)
                center=my_geo.geometry[0].bounds[1], my_geo.geometry[0].bounds[0]
                sw = center
                ne = my_geo.geometry[0].bounds[3], my_geo.geometry[0].bounds[2]
                return(ne)

# %%
def add_geojson(map3,label,bounds, geojson_string, color):
                ne = bounds[3], bounds[2]
                style_function= lambda x:{'color':color}
                folium.GeoJson(geojson_string,style_function).add_to(map3)
                map3.add_child(folium.features.LatLngPopup())
                folium.Marker(ne, popup=f'<b>{label}</b>').add_to(map3)
                
                #map3

# %%
def make_geojson(bounds):
    print(bounds)
    b=bounds
    coords = [[[b[0],b[1]], [b[0],b[3]], [b[2],b[3]], [b[2],b[1]], [b[0],b[1]]]]
    print(coords)
    my = Polygon(coords)
    return(my)

# %%
def return_map_please(geojson_file):
    f=Fmap(color='red')
    mymap = f.sat_geojson(f'./AOI/{geojson_file}')
    return(mymap)

# %%
from os import listdir
from os.path import isfile, join

def return_tif_list():
    mypath='.'
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    tif_files = [f for f in onlyfiles if f.endswith('.tif')]
    return(tif_files)

# %%
import panel as pn
pn.extension()

# %%
tif_list = return_tif_list()
print(tif_list)
# Out:
# ['HLS.S30.T11SLU.2020274T183109.v1.5_EVI.tif', 'HLS.S30.T11SLU.2020192T183921.v1.5_EVI.tif', 'HLS.S30.T11SLU.2020277T184129.v1.5_EVI.tif', 'HLS.S30.T11SLU.2020282T184301.v1.5_EVI.tif', 'HLS.S30.T11SLU.2020287T184329.v1.5_EVI.tif', 'HLS.S30.T11SLU.2020262T184041.v1.5_EVI.tif', 'HLS.S30.T11SLU.2020284T183309.v1.5_EVI.tif']

# %%
import rasterio
for red in tif_list:
    print(red)
    src=rasterio.open(red)
    print(src.bounds)
# Out:
# HLS.S30.T11SLU.2020274T183109.v1.5_EVI.tif
# BoundingBox(left=300000.0, bottom=3790200.0, right=409800.0, top=3900000.0)
# HLS.S30.T11SLU.2020192T183921.v1.5_EVI.tif
# BoundingBox(left=300000.0, bottom=3790200.0, right=409800.0, top=3900000.0)
# HLS.S30.T11SLU.2020277T184129.v1.5_EVI.tif
# BoundingBox(left=300000.0, bottom=3790200.0, right=409800.0, top=3900000.0)
# HLS.S30.T11SLU.2020282T184301.v1.5_EVI.tif
# BoundingBox(left=300000.0, bottom=3790200.0, right=409800.0, top=3900000.0)
# HLS.S30.T11SLU.2020287T184329.v1.5_EVI.tif
# BoundingBox(left=300000.0, bottom=3790200.0, right=409800.0, top=3900000.0)
# HLS.S30.T11SLU.2020262T184041.v1.5_EVI.tif
# BoundingBox(left=300000.0, bottom=3790200.0, right=409800.0, top=3900000.0)
# HLS.S30.T11SLU.2020284T183309.v1.5_EVI.tif
# BoundingBox(left=300000.0, bottom=3790200.0, right=409800.0, top=3900000.0)

# %%
import os

def make_aoi(url,label):
    fn=f'./AOI/reds_{label}.geojson'
    cmd = f'rio bounds {url} > {fn}'
    os.system(cmd)
    print(cmd)
    return(fn)

# %%
# !mkdir -p AOI

# %%
i=0
for tif in tif_list:
    url = tif_list[i]
    label=f'display{i}'
    make_aoi(url,label)
    i=i+1
# Out:
# rio bounds HLS.S30.T11SLU.2020274T183109.v1.5_EVI.tif > ./AOI/reds_display0.geojson
# rio bounds HLS.S30.T11SLU.2020192T183921.v1.5_EVI.tif > ./AOI/reds_display1.geojson
# rio bounds HLS.S30.T11SLU.2020277T184129.v1.5_EVI.tif > ./AOI/reds_display2.geojson
# rio bounds HLS.S30.T11SLU.2020282T184301.v1.5_EVI.tif > ./AOI/reds_display3.geojson
# rio bounds HLS.S30.T11SLU.2020287T184329.v1.5_EVI.tif > ./AOI/reds_display4.geojson
# rio bounds HLS.S30.T11SLU.2020262T184041.v1.5_EVI.tif > ./AOI/reds_display5.geojson
# rio bounds HLS.S30.T11SLU.2020284T183309.v1.5_EVI.tif > ./AOI/reds_display6.geojson

# %%
def return_geojson_list():
    mypath='AOI'
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    return(onlyfiles)

# %%
geojson_list = return_geojson_list()
print(geojson_list)
# Out:
# ['reds_display3.geojson', 'reds_display1.geojson', 'reds_display4.geojson', 'reds_display6.geojson', 'reds_display.geojson', 'reds_display0.geojson', 'reds_display2.geojson', 'reds_display5.geojson']

# %%
title = '## Geojson Display Panel App'

geo_select = pn.widgets.Select(name='geo1', options=geojson_list)

@pn.depends(geo_select.param.value)
def refresh_geojson_map(geo1):
    return(return_map_please(geo_select.value))

# %%
row = pn.Row(
    pn.Column(title, pn.panel(refresh_geojson_map, width=800), geo_select)
)

row.servable()
# Out:
# creating Fmap class
# creating Fmap class</br>
# creating Fmap class</br>
# creating Fmap class</br>
# creating Fmap class</br>
# Row
#     [0] Column
#         [0] Markdown(str)
#         [1] ParamFunction(function, width=800)
#         [2] Select(name='geo1', options=['reds_display3.geojson', ...], value='reds_display3.geojson')

# %%
print(geo_select)

# %%
geo_select.value

# %%
help(Fmap.map_geojson)
